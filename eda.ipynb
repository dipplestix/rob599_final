# %%
import torch
from torch_geometric.datasets import QM9
from torch_geometric.loader import DataLoader
from torch.utils.data import random_split
import torch.nn as nn

# Original dataset
dataset = QM9(root='data/QM9')

# New dataset with molecules of less than 5 atoms
small_dataset = [data for data in dataset if data.num_nodes < 10]

unique_atoms = set()
for data in dataset:
    unique_atoms.update(data.z.tolist())

print(f"Number of unique atoms in the original dataset: {len(unique_atoms)}")
print(f"Unique atomic numbers: {sorted(list(unique_atoms))}")

# Original dataset statistics
total_size = len(dataset)
train_size = int(0.8 * total_size)
val_size = int(0.1 * total_size)
test_size = total_size - train_size - val_size
print(f"Original dataset - Train size: {train_size}, Val size: {val_size}, Test size: {test_size}")

# Small dataset statistics
small_total_size = len(small_dataset)
small_train_size = int(0.8 * small_total_size)
small_val_size = int(0.1 * small_total_size)
small_test_size = small_total_size - small_train_size - small_val_size
print(f"Small dataset - Train size: {small_train_size}, Val size: {small_val_size}, Test size: {small_test_size}")

# Split original dataset
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

# Split small dataset
small_train_dataset, small_val_dataset, small_test_dataset = random_split(small_dataset, [small_train_size, small_val_size, small_test_size])

batch_size = 128

# DataLoaders for original dataset
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# DataLoaders for small dataset
small_train_loader = DataLoader(small_train_dataset, batch_size=batch_size, shuffle=True)
small_val_loader = DataLoader(small_val_dataset, batch_size=batch_size)
small_test_loader = DataLoader(small_test_dataset, batch_size=batch_size)

for batch in train_loader:
    break

for small_batch in small_train_loader:
    break

batch = small_batch
# Out:
# Number of unique atoms in the original dataset: 5
# Unique atomic numbers: [1, 6, 7, 8, 9]
# Original dataset - Train size: 104664, Val size: 13083, Test size: 13084
# Small dataset - Train size: 224, Val size: 28, Test size: 28

# %%
batch[molecule_index]
# Out:
# Data(x=[9, 11], edge_index=[2, 18], edge_attr=[18, 4], y=[1, 19], pos=[9, 3], z=[9], smiles='[H][N-]C1ON=NC(=O)O1', name='gdb_21441', idx=[1])

# %%
def calculate_rmsd(molecule_index, r):
    # Calculate RMSD between predicted and actual positions using Kabsch algorithm
    # First center both sets of coordinates by subtracting mean
    r_centered = r - r.mean(dim=0, keepdim=True)
    pos_centered = batch[molecule_index].pos - batch[molecule_index].pos.mean(dim=0, keepdim=True)

    # Calculate covariance matrix
    covariance = torch.matmul(r_centered.t(), pos_centered)

    # Perform SVD
    U, S, Vt = torch.linalg.svd(covariance)

    # Calculate optimal rotation matrix
    # Handle reflection case by ensuring right-handed coordinate system
    d = torch.linalg.det(torch.matmul(Vt.t(), U.t()))
    reflection_matrix = torch.eye(3)
    reflection_matrix[-1, -1] = d
    R = torch.matmul(torch.matmul(Vt.t(), reflection_matrix), U.t())

    # Apply rotation to centered coordinates
    r_aligned = torch.matmul(r_centered, R)

    # Calculate RMSD
    squared_diff = torch.sum((r_aligned - pos_centered) ** 2, dim=1)
    rmsd = torch.sqrt(torch.mean(squared_diff))

    return rmsd

def bond_length_loss(pred_coords, target_coords, bond_indices):
    pred_bond_lengths = torch.norm(pred_coords[bond_indices[:, 0]] - pred_coords[bond_indices[:, 1]], dim=1)
    target_bond_lengths = torch.norm(target_coords[bond_indices[:, 0]] - target_coords[bond_indices[:, 1]], dim=1)
    return torch.mean((pred_bond_lengths - target_bond_lengths) ** 2)

# %%
net = MolecularShapePredictor(embedding_dim=256, num_layers=10)
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

for e in range(100):
    loss = 0
    for i in range(20):
        # Initialize positions by placing bonded atoms 1 unit apart at random angles
        initial_r = torch.zeros_like(batch[i].pos)
        edge_index = batch[i].edge_index
        placed = torch.zeros(batch[i].num_nodes, dtype=torch.bool)
        placed[0] = True  # Start with first atom at origin
        
        # Process each edge to position atoms
        # for src, dst in edge_index.t():
            # if placed[src] and not placed[dst]:
            #     # Generate random angles
            #     theta = torch.rand(1) * 2 * torch.pi  # Random angle in xy plane
            #     phi = torch.rand(1) * torch.pi        # Random angle from z axis
                
            #     # Calculate unit vector in random direction
            #     x = torch.sin(phi) * torch.cos(theta)
            #     y = torch.sin(phi) * torch.sin(theta)
            #     z = torch.cos(phi)
            #     direction = torch.tensor([x, y, z])
                
            #     # Place atom 1 unit away from connected atom
            #     initial_r[dst] = initial_r[src] + direction
            #     placed[dst] = True
            # elif placed[dst] and not placed[src]:
            #     # Same process but in reverse direction
            #     theta = torch.rand(1) * 2 * torch.pi
            #     phi = torch.rand(1) * torch.pi
                
            #     x = torch.sin(phi) * torch.cos(theta)
            #     y = torch.sin(phi) * torch.sin(theta)
            #     z = torch.cos(phi)
            #     direction = torch.tensor([x, y, z])
                
            #     initial_r[src] = initial_r[dst] + direction
            #     placed[src] = True
        initial_r = batch[i].pos + torch.randn_like(batch[i].pos) * 0.7
        adj_matrix = create_adjacency_matrix(batch, i)
        h, r = net(batch[i].z, initial_r, adj_matrix)
        loss += .3*calculate_rmsd(i, r) + bond_length_loss(r, batch[i].pos, batch[i].edge_index.t())

    loss = loss/100
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print(f"Iteration {e+1}, Loss: {loss.item():.4f}")
# Out:
# Iteration 1, Loss: 0.2902
# Iteration 2, Loss: 0.2790
# Iteration 3, Loss: 0.3232
# Iteration 4, Loss: 0.2780
# Iteration 5, Loss: 0.3477
# Iteration 6, Loss: 0.3159
# Iteration 7, Loss: 0.3127
# Iteration 8, Loss: 0.2904
# Iteration 9, Loss: 0.2970
# Iteration 10, Loss: 0.2879
# Iteration 11, Loss: 0.3258
# Iteration 12, Loss: 0.2964
# Iteration 13, Loss: 0.3152
# Iteration 14, Loss: 0.3152
# Iteration 15, Loss: 0.3291
# Iteration 16, Loss: 0.3552
# Iteration 17, Loss: 0.2903
# Iteration 18, Loss: 0.3010
# Iteration 19, Loss: 0.3277
# Iteration 20, Loss: 0.2853
# Iteration 21, Loss: 0.3201
# Iteration 22, Loss: 0.3156
# Iteration 23, Loss: 0.2827
# Iteration 24, Loss: 0.3286
# Iteration 25, Loss: 0.3080
# Iteration 26, Loss: 0.2961
# Iteration 27, Loss: 0.3242
# Iteration 28, Loss: 0.2762
# Iteration 29, Loss: 0.2757
# Iteration 30, Loss: 0.3336
# Iteration 31, Loss: 0.3300
# Iteration 32, Loss: 0.2903
# Iteration 33, Loss: 0.3395
# Iteration 34, Loss: 0.2941
# Iteration 35, Loss: 0.2648
# Iteration 36, Loss: 0.3087
# Iteration 37, Loss: 0.2813
# Iteration 38, Loss: 0.3370
# Iteration 39, Loss: 0.2951
# Iteration 40, Loss: 0.3074
# Iteration 41, Loss: 0.3234
# Iteration 42, Loss: 0.2664
# Iteration 43, Loss: 0.3528
# Iteration 44, Loss: 0.2979
# Iteration 45, Loss: 0.3352
# Iteration 46, Loss: 0.3494
# Iteration 47, Loss: 0.3208
# Iteration 48, Loss: 0.3161
# Iteration 49, Loss: 0.3050
# Iteration 50, Loss: 0.3107
# Iteration 51, Loss: 0.3089
# Iteration 52, Loss: 0.3544
# Iteration 53, Loss: 0.3178
# Iteration 54, Loss: 0.3218
# Iteration 55, Loss: 0.3430
# Iteration 56, Loss: 0.3238
# Iteration 57, Loss: 0.3243
# Iteration 58, Loss: 0.3353
# Iteration 59, Loss: 0.3048
# Iteration 60, Loss: 0.2840
# Iteration 61, Loss: 0.3002
# Iteration 62, Loss: 0.2963
# Iteration 63, Loss: 0.3197
# Iteration 64, Loss: 0.3054
# Iteration 65, Loss: 0.2550
# Iteration 66, Loss: 0.3043
# Iteration 67, Loss: 0.3035
# Iteration 68, Loss: 0.3081
# Iteration 69, Loss: 0.3044
# Iteration 70, Loss: 0.2938
# Iteration 71, Loss: 0.2760
# Iteration 72, Loss: 0.2843
# Iteration 73, Loss: 0.3200
# Iteration 74, Loss: 0.3630
# Iteration 75, Loss: 0.2834
# Iteration 76, Loss: 0.3336
# Iteration 77, Loss: 0.3141
# Iteration 78, Loss: 0.2677
# Iteration 79, Loss: 0.2958
# Iteration 80, Loss: 0.2872
# Iteration 81, Loss: 0.3276
# Iteration 82, Loss: 0.3197
# Iteration 83, Loss: 0.3345
# Iteration 84, Loss: 0.3306
# Iteration 85, Loss: 0.3531
# Iteration 86, Loss: 0.3024
# Iteration 87, Loss: 0.2691
# Iteration 88, Loss: 0.3738
# Iteration 89, Loss: 0.2636
# Iteration 90, Loss: 0.2681
# Iteration 91, Loss: 0.2746
# Iteration 92, Loss: 0.2890
# Iteration 93, Loss: 0.2894
# Iteration 94, Loss: 0.2862
# Iteration 95, Loss: 0.2898
# Iteration 96, Loss: 0.2921
# Iteration 97, Loss: 0.2720
# Iteration 98, Loss: 0.3061
# Iteration 99, Loss: 0.3458
# Iteration 100, Loss: 0.3036

# %%
visualize_molecule(batch, 12)
# Out:
# SMILES code: [H]C1=C(N(=O)=O)ON=N1
# <div id="3dmolviewer_17324380726848822"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_17324380726848822" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17324380726848822 = null;
# var warn = document.getElementById("3dmolwarning_17324380726848822");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17324380726848822 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17324380726848822"),{backgroundColor:"white"});
# viewer_17324380726848822.zoomTo();
# 	viewer_17324380726848822.addSphere({"center": {"x": -0.06729999929666519, "y": -0.004000000189989805, "z": 0.004999999888241291}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17324380726848822.addSphere({"center": {"x": -0.014999999664723873, "y": 1.2180999517440796, "z": 0.007799999788403511}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17324380726848822.addSphere({"center": {"x": 0.9825999736785889, "y": 1.9155999422073364, "z": 0.0027000000700354576}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17324380726848822.addSphere({"center": {"x": -1.2999000549316406, "y": 1.8880000114440918, "z": 0.01889999955892563}, "radius": 0.3, "color": "black", "alpha": 0.8});
# 	viewer_17324380726848822.addSphere({"center": {"x": -2.554800033569336, "y": 1.371399998664856, "z": 0.02630000002682209}, "radius": 0.3, "color": "black", "alpha": 0.8});
# 	viewer_17324380726848822.addSphere({"center": {"x": -3.39520001411438, "y": 2.455899953842163, "z": 0.035599999129772186}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17324380726848822.addSphere({"center": {"x": -2.7428998947143555, "y": 3.5318000316619873, "z": 0.033399999141693115}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17324380726848822.addSphere({"center": {"x": -1.3413000106811523, "y": 3.2060999870300293, "z": 0.023399999365210533}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17324380726848822.addSphere({"center": {"x": -2.894700050354004, "y": 0.351500004529953, "z": 0.025699999183416367}, "radius": 0.3, "color": "white", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -0.06729999929666519, "y": -0.004000000189989805, "z": 0.004999999888241291}, "end": {"x": -0.014999999664723873, "y": 1.2180999517440796, "z": 0.007799999788403511}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -0.014999999664723873, "y": 1.2180999517440796, "z": 0.007799999788403511}, "end": {"x": -0.06729999929666519, "y": -0.004000000189989805, "z": 0.004999999888241291}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -0.014999999664723873, "y": 1.2180999517440796, "z": 0.007799999788403511}, "end": {"x": 0.9825999736785889, "y": 1.9155999422073364, "z": 0.0027000000700354576}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -0.014999999664723873, "y": 1.2180999517440796, "z": 0.007799999788403511}, "end": {"x": -1.2999000549316406, "y": 1.8880000114440918, "z": 0.01889999955892563}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": 0.9825999736785889, "y": 1.9155999422073364, "z": 0.0027000000700354576}, "end": {"x": -0.014999999664723873, "y": 1.2180999517440796, "z": 0.007799999788403511}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -1.2999000549316406, "y": 1.8880000114440918, "z": 0.01889999955892563}, "end": {"x": -0.014999999664723873, "y": 1.2180999517440796, "z": 0.007799999788403511}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -1.2999000549316406, "y": 1.8880000114440918, "z": 0.01889999955892563}, "end": {"x": -2.554800033569336, "y": 1.371399998664856, "z": 0.02630000002682209}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -1.2999000549316406, "y": 1.8880000114440918, "z": 0.01889999955892563}, "end": {"x": -1.3413000106811523, "y": 3.2060999870300293, "z": 0.023399999365210533}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -2.554800033569336, "y": 1.371399998664856, "z": 0.02630000002682209}, "end": {"x": -1.2999000549316406, "y": 1.8880000114440918, "z": 0.01889999955892563}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -2.554800033569336, "y": 1.371399998664856, "z": 0.02630000002682209}, "end": {"x": -3.39520001411438, "y": 2.455899953842163, "z": 0.035599999129772186}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -2.554800033569336, "y": 1.371399998664856, "z": 0.02630000002682209}, "end": {"x": -2.894700050354004, "y": 0.351500004529953, "z": 0.025699999183416367}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -3.39520001411438, "y": 2.455899953842163, "z": 0.035599999129772186}, "end": {"x": -2.554800033569336, "y": 1.371399998664856, "z": 0.02630000002682209}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -3.39520001411438, "y": 2.455899953842163, "z": 0.035599999129772186}, "end": {"x": -2.7428998947143555, "y": 3.5318000316619873, "z": 0.033399999141693115}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -2.7428998947143555, "y": 3.5318000316619873, "z": 0.033399999141693115}, "end": {"x": -3.39520001411438, "y": 2.455899953842163, "z": 0.035599999129772186}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -2.7428998947143555, "y": 3.5318000316619873, "z": 0.033399999141693115}, "end": {"x": -1.3413000106811523, "y": 3.2060999870300293, "z": 0.023399999365210533}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -1.3413000106811523, "y": 3.2060999870300293, "z": 0.023399999365210533}, "end": {"x": -1.2999000549316406, "y": 1.8880000114440918, "z": 0.01889999955892563}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -1.3413000106811523, "y": 3.2060999870300293, "z": 0.023399999365210533}, "end": {"x": -2.7428998947143555, "y": 3.5318000316619873, "z": 0.033399999141693115}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.addCylinder({"start": {"x": -2.894700050354004, "y": 0.351500004529953, "z": 0.025699999183416367}, "end": {"x": -2.554800033569336, "y": 1.371399998664856, "z": 0.02630000002682209}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380726848822.zoomTo();
# viewer_17324380726848822.render();
# });
# </script>
# tensor([8, 7, 8, 6, 6, 7, 7, 8, 1])
#
# Graph information:
# Number of nodes: 9
# Number of edges: 18
# Node features shape: torch.Size([9, 11])

# %%
initial_r = batch[12].pos + torch.randn_like(batch[12].pos) * 0.1
h, pos = net(batch[12].z, initial_r, create_adjacency_matrix(batch, 12))
visualize_molecule(batch, 12, pos)
# Out:
# SMILES code: [H]C1=C(N(=O)=O)ON=N1
# <div id="3dmolviewer_17324380733707979"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_17324380733707979" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17324380733707979 = null;
# var warn = document.getElementById("3dmolwarning_17324380733707979");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17324380733707979 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17324380733707979"),{backgroundColor:"white"});
# viewer_17324380733707979.zoomTo();
# 	viewer_17324380733707979.addSphere({"center": {"x": -0.2404334843158722, "y": -0.013193493708968163, "z": 0.02111724391579628}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17324380733707979.addSphere({"center": {"x": -0.13864274322986603, "y": 1.1181696653366089, "z": -0.1983310878276825}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17324380733707979.addSphere({"center": {"x": 1.0559229850769043, "y": 1.8858088254928589, "z": 0.006267176941037178}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17324380733707979.addSphere({"center": {"x": -1.2978792190551758, "y": 1.850447416305542, "z": 0.07352559268474579}, "radius": 0.3, "color": "black", "alpha": 0.8});
# 	viewer_17324380733707979.addSphere({"center": {"x": -2.688347578048706, "y": 1.5607082843780518, "z": 0.08254390954971313}, "radius": 0.3, "color": "black", "alpha": 0.8});
# 	viewer_17324380733707979.addSphere({"center": {"x": -3.34383487701416, "y": 2.618344306945801, "z": 0.08265922963619232}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17324380733707979.addSphere({"center": {"x": -2.704914093017578, "y": 3.65779185295105, "z": -0.1562645435333252}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17324380733707979.addSphere({"center": {"x": -1.2347679138183594, "y": 3.198014259338379, "z": 0.0834597498178482}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17324380733707979.addSphere({"center": {"x": -3.0814015865325928, "y": 0.42661789059638977, "z": 0.15606297552585602}, "radius": 0.3, "color": "white", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -0.2404334843158722, "y": -0.013193493708968163, "z": 0.02111724391579628}, "end": {"x": -0.13864274322986603, "y": 1.1181696653366089, "z": -0.1983310878276825}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -0.13864274322986603, "y": 1.1181696653366089, "z": -0.1983310878276825}, "end": {"x": -0.2404334843158722, "y": -0.013193493708968163, "z": 0.02111724391579628}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -0.13864274322986603, "y": 1.1181696653366089, "z": -0.1983310878276825}, "end": {"x": 1.0559229850769043, "y": 1.8858088254928589, "z": 0.006267176941037178}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -0.13864274322986603, "y": 1.1181696653366089, "z": -0.1983310878276825}, "end": {"x": -1.2978792190551758, "y": 1.850447416305542, "z": 0.07352559268474579}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": 1.0559229850769043, "y": 1.8858088254928589, "z": 0.006267176941037178}, "end": {"x": -0.13864274322986603, "y": 1.1181696653366089, "z": -0.1983310878276825}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -1.2978792190551758, "y": 1.850447416305542, "z": 0.07352559268474579}, "end": {"x": -0.13864274322986603, "y": 1.1181696653366089, "z": -0.1983310878276825}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -1.2978792190551758, "y": 1.850447416305542, "z": 0.07352559268474579}, "end": {"x": -2.688347578048706, "y": 1.5607082843780518, "z": 0.08254390954971313}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -1.2978792190551758, "y": 1.850447416305542, "z": 0.07352559268474579}, "end": {"x": -1.2347679138183594, "y": 3.198014259338379, "z": 0.0834597498178482}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -2.688347578048706, "y": 1.5607082843780518, "z": 0.08254390954971313}, "end": {"x": -1.2978792190551758, "y": 1.850447416305542, "z": 0.07352559268474579}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -2.688347578048706, "y": 1.5607082843780518, "z": 0.08254390954971313}, "end": {"x": -3.34383487701416, "y": 2.618344306945801, "z": 0.08265922963619232}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -2.688347578048706, "y": 1.5607082843780518, "z": 0.08254390954971313}, "end": {"x": -3.0814015865325928, "y": 0.42661789059638977, "z": 0.15606297552585602}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -3.34383487701416, "y": 2.618344306945801, "z": 0.08265922963619232}, "end": {"x": -2.688347578048706, "y": 1.5607082843780518, "z": 0.08254390954971313}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -3.34383487701416, "y": 2.618344306945801, "z": 0.08265922963619232}, "end": {"x": -2.704914093017578, "y": 3.65779185295105, "z": -0.1562645435333252}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -2.704914093017578, "y": 3.65779185295105, "z": -0.1562645435333252}, "end": {"x": -3.34383487701416, "y": 2.618344306945801, "z": 0.08265922963619232}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -2.704914093017578, "y": 3.65779185295105, "z": -0.1562645435333252}, "end": {"x": -1.2347679138183594, "y": 3.198014259338379, "z": 0.0834597498178482}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -1.2347679138183594, "y": 3.198014259338379, "z": 0.0834597498178482}, "end": {"x": -1.2978792190551758, "y": 1.850447416305542, "z": 0.07352559268474579}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -1.2347679138183594, "y": 3.198014259338379, "z": 0.0834597498178482}, "end": {"x": -2.704914093017578, "y": 3.65779185295105, "z": -0.1562645435333252}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.addCylinder({"start": {"x": -3.0814015865325928, "y": 0.42661789059638977, "z": 0.15606297552585602}, "end": {"x": -2.688347578048706, "y": 1.5607082843780518, "z": 0.08254390954971313}, "radius": 0.05, "color": "gray", "alpha": 0.8});
# 	viewer_17324380733707979.zoomTo();
# viewer_17324380733707979.render();
# });
# </script>
# tensor([8, 7, 8, 6, 6, 7, 7, 8, 1])
#
# Graph information:
# Number of nodes: 9
# Number of edges: 18
# Node features shape: torch.Size([9, 11])

# %%
calculate_rmsd(12, pos)
# Out:
# tensor(0.2878, grad_fn=<SqrtBackward0>)
